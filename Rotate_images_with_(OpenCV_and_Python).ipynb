# %% [markdown]
# <a href="https://colab.research.google.com/github/gentleman101/Deep_Learning/blob/main/Rotate_images_with_(OpenCV_and_Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import numpy as np
import argparse
import imutils
import cv2
from IPython.display import Image
from matplotlib import pyplot as plt
from scipy import ndimage

# %%
# Viewing our image
image='/content/drive/MyDrive/DATA/Carnivores_Data/test/cheetah/cheetah_000_val_resized.jpg'
Image(image)

# %%
# load the image from disk
image = cv2.imread(image)

# %%
# loop over the rotation angles
for angle in np.arange(0, 90, 15):
  rotated = imutils.rotate_bound(image, angle)
  plt.imshow(rotated)
  plt.show()
  cv2.waitKey(0)

# %%
# Rotation using scipy
#rotation angle in degree
rotated = ndimage.rotate(image, 45)
plt.imshow(rotated)

# %% [markdown]
# ## Similar Implementation on python
